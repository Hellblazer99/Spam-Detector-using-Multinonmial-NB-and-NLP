# %%
#!conda install nltk
import nltk
#nltk.download()

# %%
nltk.download_shell()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q

# %%
messages = [line.rstrip() for line in open('smsspamcollection/SMSSpamCollection')]

# %%
print(len(messages))
# Out:
# 5574

# %%
for x in messages:
    print(len(x))
# Out:
# 115
# 33
# 160
# 53
# 65
# 152
# 81
# 164
# 162
# 159
# 113
# 141
# 160
# 200
# 39
# 154
# 30
# 85
# 60
# 160
# 45
# 51
# 56
# 92
# 61
# 148
# 34
# 138
# 79
# 68
# 134
# 192
# 33
# 88
# 163
# 126
# 51
# 32
# 31
# 159
# 86
# 146
# 177
# 23
# 76
# 36
# 49
# 35
# 71
# 152
# 62
# 128
# 84
# 293
# 125
# 80
# 165
# 38
# 26
# 44
# 112
# 52
# 29
# 60
# 114
# 157
# 126
# 164
# 83
# 38
# 50
# 33
# 49
# 46
# 24
# 47
# 77
# 54
# 46
# 80
# 26
# 35
# 36
# 40
# 18
# 59
# 125
# 148
# 46
# 45
# 62
# 198
# 145
# 142
# 111
# 163
# 37
# 55
# 182
# 35
# 61
# 85
# 80
# 164
# 187
# 48
# 99
# 47
# 86
# 119
# 34
# 44
# 35
# 100
# 163
# 147
# 160
# 156
# 75
# 90
# 149
# 161
# 57
# 161
# 55
# 42
# 24
# 248
# 26
# 111
# 32
# 13
# 43
# 29
# 130
# 167
# 42
# 38
# 50
# 160
# 89
# 37
# 31
# 160
# 46
# 29
# 52
# 164
# 88
# 37
# 34
# 49
# 63
# 29
# 164
# 388
# 32
# 31
# 161
# 129
# 150
# 119
# 68
# 89
# 157
# 160
# 55
# 161
# 78
# 70
# 63
# 54
# 97
# 36
# 108
# 65
# 69
# 30
# 150
# 70
# 130
# 163
# 27
# 69
# 28
# 30
# ...

# %%
print(messages[50])
# Out:
# ham	What you thinked about me. First time you saw me in class.

# %%
for mess_no, message in enumerate(messages[:10]):
    print(mess_no,message)
    print('\n')
# Out:
# 0 ham	Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
#
#
# 1 ham	Ok lar... Joking wif u oni...
#
#
# 2 spam	Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
#
#
# 3 ham	U dun say so early hor... U c already then say...
#
#
# 4 ham	Nah I don't think he goes to usf, he lives around here though
#
#
# 5 spam	FreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for it still? Tb ok! XxX std chgs to send, £1.50 to rcv
#
#
# 6 ham	Even my brother is not like to speak with me. They treat me like aids patent.
#
#
# 7 ham	As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune
#
#
# ...

# %% [markdown]
# ### Analyzing Features

# %%
import pandas as pd

# %%
messages = pd.read_csv('smsspamcollection/SMSSpamCollection',sep='\t',names=['label','messages'])

# %%
messages.head()
# Out:
#   label                                           messages
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
 messages.describe()
# Out:
#        label                messages
# count   5572                    5572
# unique     2                    5169
# top      ham  Sorry, I'll call later
# freq    4825                      30

# %%
messages.groupby('label').describe()
# Out:
#       messages
#          count unique                                                top freq
# label
# ham       4825   4516                             Sorry, I'll call later   30
# spam       747    653  Please call our customer service representativ...    4

# %%
messages['length'] = messages['messages'].apply(len)

# %%
messages.head()
# Out:
#   label                                           messages  length
# 0   ham  Go until jurong point, crazy.. Available only ...     111
# 1   ham                      Ok lar... Joking wif u oni...      29
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...     155
# 3   ham  U dun say so early hor... U c already then say...      49
# 4   ham  Nah I don't think he goes to usf, he lives aro...      61

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
messages['length'].plot.hist(bins = 150)

# %%
messages['length'].describe()
# Out:
# count    5572.000000
# mean       80.489950
# std        59.942907
# min         2.000000
# 25%        36.000000
# 50%        62.000000
# 75%       122.000000
# max       910.000000
# Name: length, dtype: float64

# %%
print(messages[messages['length']==910]['messages'].iloc[0])
# Out:
# For me the love should start with attraction.i should feel that I need her every time around me.she should be the first thing which comes in my thoughts.I would start the day and end it with her.she should be there every time I dream.love will be then when my every breath has her name.my life should happen around her.my life will be named to her.I would cry for her.will give all my happiness and take all her sorrows.I will be ready to fight with anyone for her.I will be in love when I will be doing the craziest things for her.love will be when I don't have to proove anyone that my girl is the most beautiful lady on the whole planet.I will always be singing praises for her.love will be when I start up making chicken curry and end up makiing sambar.life will be the most beautiful then.will get every morning and thank god for the day because she is with me.I would like to say a lot..will tell later..

# %%
messages.hist(column = 'length', by='label', bins=60,figsize=(12,4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa08849f7b8>,
# ...
#       dtype=object)

# %% [markdown]
# ### Removing Puncs and Stopwords

# %%
import string

# %%
mess = 'Sample Message!! Notice; it has puncs'

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
nopunc = [c for c in mess if c not in string.punctuation]

# %%
print(nopunc)
# Out:
# ['S', 'a', 'm', 'p', 'l', 'e', ' ', 'M', 'e', 's', 's', 'a', 'g', 'e', ' ', 'N', 'o', 't', 'i', 'c', 'e', ' ', 'i', 't', ' ', 'h', 'a', 's', ' ', 'p', 'u', 'n', 'c', 's']

# %%
from nltk.corpus import stopwords

# %%
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
nopunc = ''.join(nopunc)

# %%
nopunc
# Out:
# 'Sample Message Notice it has puncs'

# %%
x = ['a','b','c','d']

# %%
y = '+++'.join(x)
y
# Out:
# 'a+++b+++c+++d'

# %%
nopunc.split()
# Out:
# ['Sample', 'Message', 'Notice', 'it', 'has', 'puncs']

# %%
clean_mess = [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]

# %%
clean_mess
# Out:
# ['Sample', 'Message', 'Notice', 'puncs']

# %% [markdown]
# ### Putting it all together in a function

# %%
def text_proc(mess):
    """
    1. remove punc
    2. remove stop words
    3. return list of clean text words
    """
    nopunc = [char for char in mess if char not in string.punctuation]
    
    nopunc = ''.join(nopunc)
    
    return [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]

# %%
messages.head()
# Out:
#   label                                           messages  length
# 0   ham  Go until jurong point, crazy.. Available only ...     111
# 1   ham                      Ok lar... Joking wif u oni...      29
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...     155
# 3   ham  U dun say so early hor... U c already then say...      49
# 4   ham  Nah I don't think he goes to usf, he lives aro...      61

# %%
messages['messages'].head(5).apply(text_proc)
# Out:
# 0    [Go, jurong, point, crazy, Available, bugis, n...
# 1                       [Ok, lar, Joking, wif, u, oni]
# 2    [Free, entry, 2, wkly, comp, win, FA, Cup, fin...
# 3        [U, dun, say, early, hor, U, c, already, say]
# 4    [Nah, dont, think, goes, usf, lives, around, t...
# Name: messages, dtype: object

# %%
messages['messages'].iloc[0]
# Out:
# 'Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...'

# %% [markdown]
# ## Vectorizing

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
bow_transformer = CountVectorizer(analyzer=text_proc).fit(messages['messages'])

# %%
import sys
sys.getsizeof(bow_transformer)
# Out:
# 56

# %%
print(len(bow_transformer.vocabulary_))
# Out:
# 11425

# %%
mess4 = messages['messages'].iloc[3]
print(mess4)
# Out:
# U dun say so early hor... U c already then say...

# %%
bow4 = bow_transformer.transform([mess4])

# %%
print(bow4)
# Out:
#   (0, 4068)	2
#   (0, 4629)	1
#   (0, 5261)	1
#   (0, 6204)	1
#   (0, 6222)	1
#   (0, 7186)	1
#   (0, 9554)	2

# %%
print(bow4.shape)
# Out:
# (1, 11425)

# %%
bow_transformer.get_feature_names()[4068]
# Out:
# 'U'

# %%
bow_transformer.get_feature_names()[9554]
# Out:
# 'say'

# %%
messages_bow = bow_transformer.transform(messages['messages'])

# %%
print('Shape of Sparse Matrix: ',messages_bow.shape)
# Out:
# Shape of Sparse Matrix:  (5572, 11425)

# %%
messages_bow.nnz
# Out:
# 50548

# %%
sparsity = (100.0 * messages_bow.nnz / (messages_bow.shape[0] * messages_bow.shape[1]))
print('sparsity: {}'.format((sparsity)))
# Out:
# sparsity: 0.07940295412668218

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# %%
tfidf = TfidfTransformer().fit(messages_bow)

# %%
tfidf_transformer = TfidfTransformer().fit(messages_bow)

# %%
tfidf4 = tfidf_transformer.transform(bow4)

# %%
print(tfidf4)
# Out:
#   (0, 9554)	0.5385626262927564
#   (0, 7186)	0.4389365653379857
#   (0, 6222)	0.3187216892949149
#   (0, 6204)	0.29953799723697416
#   (0, 5261)	0.29729957405868723
#   (0, 4629)	0.26619801906087187
#   (0, 4068)	0.40832589933384067

# %%
tfidf_transformer.idf_[bow_transformer.vocabulary_['university']]
# Out:
# 8.527076498901426

# %%
messages_tfidf = tfidf_transformer.transform(messages_bow)

# %% [markdown]
# ### Classification

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
spam_detect_model = MultinomialNB().fit(messages_tfidf,messages['label'])

# %%
spam_detect_model.predict(tfidf4)[0]
# Out:
# 'ham'

# %%
messages['label'][3]
# Out:
# 'ham'

# %%
all_pred = spam_detect_model.predict(messages_tfidf)

# %%
all_pred
# Out:
# array(['ham', 'ham', 'spam', ..., 'ham', 'ham', 'ham'], dtype='<U4')

# %% [markdown]
# #### Here the entire data was used for training and the same data was used to test it. Not recommended.
# ### Hence using Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
msg_train, msg_test, label_train, label_test = train_test_split(messages['messages'],messages['label'],test_size=0.3)

# %%
msg_train
# Out:
# 3546                            Thank You meet you monday
# 1153                               Ok i go change also...
# 1797    Hey, can you tell me blake's address? Carlos w...
# 4592    Well done ENGLAND! Get the official poly ringt...
# 5299    Well good morning mr . Hows london treatin' ya...
# 4231                              And several to you sir.
# 3922    Do 1 thing! Change that sentence into: "Becaus...
# 4433    Dont think you need yellow card for uk travel....
# 1586    I was wondering if it would be okay for you to...
# 5103    In other news after hassling me to get him wee...
# 5216                        I am late. I will be there at
# 5075    I want to sent  &lt;#&gt; mesages today. Thats...
# 4508    He neva grumble but i sad lor... Hee... Buy tm...
# 3651    We are hoping to get away by 7, from Langport....
# 1526                     Pls pls find out from aunt nike.
# 3215    Babe, have you got enough money to pick up bre...
# ...

# %% [markdown]
# #### Buliding a pipeline

# %%
from sklearn.pipeline import Pipeline

# %%
pipeline = Pipeline([
    ('bow',CountVectorizer(analyzer = text_proc)),
    ('tfidf',TfidfTransformer()),
    ('classifier',MultinomialNB())
])

# %%
pipeline.fit(msg_train,label_train)
# Out:
# Pipeline(memory=None,
#      steps=[('bow', CountVectorizer(analyzer=<function text_proc at 0x7fa0882d7158>, binary=False,
#         decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=1, ngram_range=(1, 1), preprocessor=None,...f=False, use_idf=True)), ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %%
predictions = pipeline.predict(msg_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(label_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.95      1.00      0.98      1436
#         spam       1.00      0.69      0.82       236
#
#    micro avg       0.96      0.96      0.96      1672
#    macro avg       0.98      0.85      0.90      1672
# weighted avg       0.96      0.96      0.95      1672
